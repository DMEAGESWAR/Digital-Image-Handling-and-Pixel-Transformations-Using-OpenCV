# %% [markdown]
# # Ex. No: 01
# ## Image Handling and Pixel Transformations Using OpenCV
#
# **Name :** D MEAGESWAR         **Reg. No :** 212224230154         **Slot No :** T2-DIPT-2026

# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Read the image ('Eagle_in_Flight.jpg') using OpenCV imread() as a grayscale image.

# %%
img_bgr=cv2.imread("Eagle_in_Flight.jpg")

# %% [markdown]
# 2. Print the image width, height & Channel

# %%
img_bgr.shape
# Out:
# (600, 768, 3)

# %% [markdown]
# 3. Display the image using matplotlib imshow().

# %%
plt.imshow(img_bgr,cmap="grey")
plt.title("grey image")
# Out:
# Text(0.5, 1.0, 'grey image')

# %%
img1_bgr=cv2.imread("boy.jpg")

# %%
plt.imshow(img1_bgr[:,:,::-1])
plt.title("zane")
# Out:
# Text(0.5, 1.0, 'zane')

# %%
img2_bgr=cv2.imread("Apollo-11-launch.jpg")

# %%
plt.imshow(img2_bgr)
plt.title("APOLLO")
# Out:
# Text(0.5, 1.0, 'APOLLO')

# %%
img3_bgr=cv2.imread("download.jpg")

# %%
plt.imshow(img3_bgr[:,:,::-1])

# %%
img4_bgr=cv2.imread("images.jpg")

# %%
plt.imshow(img4_bgr[:,:,::-1])

# %% [markdown]
# 4. Save the image as a PNG file using OpenCV imwrite().

# %%
cv2.imwrite('output.png',img4_bgr)
# Out:
# True

# %% [markdown]
# 5. Read the saved image above as a color image using cv2.cvtColor().

# %%
color_image = cv2.cvtColor(img4_bgr, cv2.COLOR_BGRA2RGBA)

# %% [markdown]
# 6. Display the Colour image using matplotlib imshow() & Print the image width, height & channel

# %%
plt.imshow(color_image)

# %%
plt.figure(figsize = [20,10])
plt.subplot(221);plt.imshow(img4_bgr[:,:,::-1]);plt.title("HOUSE")
plt.subplot(222);plt.imshow(img2_bgr);plt.title("ROCKET")
plt.subplot(223);plt.imshow(img_bgr[:,:,::-1]);plt.title("EAGLE")
# Out:
# Text(0.5, 1.0, 'EAGLE')

# %% [markdown]
# 7. Crop the image to extract any specific (Eagle alone)  object from the image.

# %%
crop = img_bgr[20:400,200:600]
plt.subplot(221);plt.imshow(crop[:,:,::-1]);plt.title("CROPPED")
plt.subplot(122);plt.imshow(img_bgr);plt.title("REAL")
# Out:
# Text(0.5, 1.0, 'REAL')

# %% [markdown]
# 8. Resize the image up by a factor of 2x.

# %%
resized = cv2.resize(crop,None,fx = 2,fy = 1)
plt.imshow(resized)

# %% [markdown]
# 9. Flip the cropped/resized image horizontally. (Eagle Image)

# %%
flipped =  cv2.flip(resized,1)
plt.imshow(flipped)

# %% [markdown]
# 10. Read in the image ('Apollo-11-launch.jpg').

# %%
image = cv2.imread('Apollo-11-launch.jpg')

# %% [markdown]
# 11. Add the following text to the dark area at the bottom of the image (centered on the image):

# %%
text = 'Apollo 11 Saturn V Launch, July 16, 1969'
font_face = cv2.FONT_HERSHEY_PLAIN
# YOUR CODE HERE: use putText()
withtext =  cv2.putText(image,text,(400,700),font_face,2,(255,0,0),5)
plt.imshow(image)

# %% [markdown]
# 12. Draw a magenta rectangle that encompasses the launch tower and the rocket.

# %%
# rect_color = magenta
# YOUR CODE HERE
rect_img = cv2.rectangle(image,(400,100),(800,600),(0,255,0),5)

# %% [markdown]
# 13. Display the final annotated image.

# %%
plt.imshow(rect_img)

# %% [markdown]
# 14. Read the image ('boy.jpg').

# %%
boy_image  = cv2.imread("boy.jpg")

# %% [markdown]
# 15. Adjust the brightness of the image.

# %%
# Create a matrix of ones (with data type float64)
# matrix_ones = 

matrix_ones = np.ones(boy_image.shape,dtype='uint8') 
bright = matrix_ones*50

# %% [markdown]
# 16. Create brighter and darker images.

# %%
img_brighter = cv2.add(boy_image, bright)
img_darker = cv2.subtract(boy_image, bright)

# %% [markdown]
# 17. Display the images (Original Image, Darker Image, Brighter Image).

# %%
plt.figure(figsize=[20,10])
plt.subplot(131)
plt.imshow(img_brighter[:,:,::-1])
plt.title("Brighter")
plt.subplot(132)
plt.imshow(boy_image[:,:,::-1])
plt.title("Original")
plt.subplot(133)
plt.imshow(img_darker[:,:,::-1])
plt.title("Darker")
# Out:
# Text(0.5, 1.0, 'Darker')

# %% [markdown]
# 18. Modify the image contrast.

# %%
matrix1 = np.ones(boy_image.shape, dtype=np.float64) * 1.1
matrix2 = np.ones(boy_image.shape, dtype=np.float64) * 1.2

matrix3 = np.ones(boy_image.shape, dtype=np.float64) * 0.1

img_float = boy_image.astype(np.float64)
img_higher1 = img_float * matrix1
img_higher2 = img_float * matrix2
img_lower1 = img_float * matrix3

# %% [markdown]
# 19. Display the images (Original, Lower Contrast, Higher Contrast).

# %%
plt.figure(figsize=[20,10])
plt.subplot(131)
plt.imshow(img_higher1[:,:,::-1])
plt.title("Higher Contrast")
plt.subplot(132)
plt.imshow(boy_image[:,:,::-1])
plt.title("Original")
plt.subplot(133)
plt.imshow(img_lower1[:,:,::-1])
plt.title("Lower Contrast")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..280.5].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..25.5].
# Text(0.5, 1.0, 'Lower Contrast')

# %% [markdown]
# 20. Split the image (boy.jpg) into the B,G,R components & Display the channels.

# %%
img2 = cv2.imread("boy.jpg")
B, G, R = cv2.split(img2)
plt.figure(figsize=[20,10])

plt.subplot(141)
plt.imshow(B)
plt.title("Blue")
plt.axis("off")

plt.subplot(142)
plt.imshow(G)
plt.title("Green")
plt.axis("off")

plt.subplot(143)
plt.imshow(R)
plt.title("Red")
plt.axis("off")

plt.subplot(144)
plt.imshow(img2[:,:,::-1])
plt.title("Original")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(359.5), np.float64(-0.5))

# %% [markdown]
# 21. _merged the R, G, B , display along with orginal image

# %%
merged_img2 = cv2.merge((B,G,R))
plt.figure(figsize = [20,10])

plt.subplot(121)
plt.imshow(merged_img2[:,:,::-1])
plt.title("merged image")
plt.axis("off")

plt.subplot(122)
plt.imshow(img2[:,:,::-1])
plt.title("orignal")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(359.5), np.float64(-0.5))

# %% [markdown]
# 22. Split the image into the H, S, V components &  Display the channels.

# %%
hsv_img = cv2.cvtColor(img2, cv2.COLOR_BGR2HSV)
H, S, V = cv2.split(hsv_img)
plt.figure(figsize = [20,10])

plt.subplot(131)
plt.imshow(H)
plt.title("Hue")
plt.axis("off")

plt.subplot(132)
plt.imshow(S)
plt.title("Saturation")
plt.axis("off")

plt.subplot(133)
plt.imshow(V)
plt.title("Value")
plt.axis("off")
plt.show()

# %% [markdown]
# 23. _merged the H, S, V, display along with orginal image

# %%
merged_img3 = cv2.merge((H,S,V))
plt.figure(figsize = [20,10])

final_image = cv2.cvtColor(merged_img3, cv2.COLOR_HSV2BGR)

plt.subplot(121)
plt.imshow(final_image[:,:,::-1])
plt.title("Merged image")
plt.axis("off")

plt.subplot(122)
plt.imshow(img2[:,:,::-1])
plt.title("Original image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(359.5), np.float64(-0.5))
